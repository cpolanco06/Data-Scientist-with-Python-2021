# %% [markdown]
# ## 1. Welcome!
# <p><img src="https://assets.datacamp.com/production/project_1170/img/office_cast.jpeg" alt="Markdown">.</p>
# <p><strong>The Office!</strong> What started as a British mockumentary series about office culture in 2001 has since spawned ten other variants across the world, including an Israeli version (2010-13), a Hindi version (2019-), and even a French Canadian variant (2006-2007). Of all these iterations (including the original), the American series has been the longest-running, spanning 201 episodes over nine seasons.</p>
# <p>In this notebook, we will take a look at a dataset of The Office episodes, and try to understand how the popularity and quality of the series varied over time. To do so, we will use the following dataset: <code>datasets/office_episodes.csv</code>, which was downloaded from Kaggle <a href="https://www.kaggle.com/nehaprabhavalkar/the-office-dataset">here</a>.</p>
# <p>This dataset contains information on a variety of characteristics of each episode. In detail, these are:
# <br></p>
# <div style="background-color: #efebe4; color: #05192d; text-align:left; vertical-align: middle; padding: 15px 25px 15px 25px; line-height: 1.6;">
#     <div style="font-size:20px"><b>datasets/office_episodes.csv</b></div>
# <ul>
#     <li><b>episode_number:</b> Canonical episode number.</li>
#     <li><b>season:</b> Season in which the episode appeared.</li>
#     <li><b>episode_title:</b> Title of the episode.</li>
#     <li><b>description:</b> Description of the episode.</li>
#     <li><b>ratings:</b> Average IMDB rating.</li>
#     <li><b>votes:</b> Number of votes.</li>
#     <li><b>viewership_mil:</b> Number of US viewers in millions.</li>
#     <li><b>duration:</b> Duration in number of minutes.</li>
#     <li><b>release_date:</b> Airdate.</li>
#     <li><b>guest_stars:</b> Guest stars in the episode (if any).</li>
#     <li><b>director:</b> Director of the episode.</li>
#     <li><b>writers:</b> Writers of the episode.</li>
#     <li><b>has_guests:</b> True/False column for whether the episode contained guest stars.</li>
#     <li><b>scaled_ratings:</b> The ratings scaled from 0 (worst-reviewed) to 1 (best-reviewed).</li>
# </ul>
#     </div>

# %%
# Use this cell to begin your analysis, and add as many as you would like!

# Import pandas and matplotlib.pyplot
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [11, 7]

# Read in the csv as a DataFrame
#office_df = pd.read_csv('datasets/office_episodes.csv')
office_df = pd.read_csv('datasets/office_episodes.csv', parse_dates=['release_date'])
office_df.info()
office_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   episode_number  188 non-null    int64
#  1   season          188 non-null    int64
#  2   episode_title   188 non-null    object
#  3   description     188 non-null    object
#  4   ratings         188 non-null    float64
#  5   votes           188 non-null    int64
#  6   viewership_mil  188 non-null    float64
#  7   duration        188 non-null    int64
#  8   release_date    188 non-null    datetime64[ns]
#  9   guest_stars     29 non-null     object
#  10  director        188 non-null    object
#  11  writers         188 non-null    object
#  12  has_guests      188 non-null    bool
#  13  scaled_ratings  188 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(4), object(5)
# memory usage: 19.4+ KB
#      episode_number  season     episode_title  \
# 0                 0       1             Pilot
# 1                 1       1     Diversity Day
# 2                 2       1       Health Care
# 3                 3       1      The Alliance
# 4                 4       1        Basketball
# ..              ...     ...               ...
# 183             183       9     Stairmageddon
# 184             184       9    Paper Airplane
# 185             185       9  Livin' the Dream
# 186             186       9          A.A.R.M.
# 187             187       9            Finale
#
#                                            description  ratings  votes  \
# 0    The premiere episode introduces the boss and s...      7.5   4936
# 1    Michael's off color remark puts a sensitivity ...      8.3   4801
# 2    Michael leaves Dwight in charge of picking the...      7.8   4024
# 3    Just for a laugh, Jim agrees to an alliance wi...      8.1   3915
# 4    Michael and his staff challenge the warehouse ...      8.4   4294
# ..                                                 ...      ...    ...
# 183  Dwight shoots Stanley with a bull tranquilizer...      8.0   1985
# 184  The employees hold a paper airplane competitio...      8.0   2007
# 185  Dwight becomes regional manager after Andy qui...      9.0   2831
# 186  Dwight prepares for a marriage proposal and hi...      9.5   3914
# 187  One year later, Dunder Mifflin employees past ...      9.8  10515
#
#      viewership_mil  duration release_date  \
# 0             11.20        23   2005-03-24
# 1              6.00        23   2005-03-29
# 2              5.80        22   2005-04-05
# 3              5.40        23   2005-04-12
# 4              5.00        23   2005-04-19
# ..              ...       ...          ...
# 183            3.83        22   2013-04-11
# 184            3.25        22   2013-04-25
# 185            3.51        42   2013-05-02
# 186            4.56        43   2013-05-09
# 187            5.69        51   2013-05-16
#
#                                            guest_stars         director  \
# 0                                                  NaN       Ken Kwapis
# 1                                                  NaN       Ken Kwapis
# 2                                                  NaN  Ken Whittingham
# 3                                                  NaN     Bryan Gordon
# 4                                                  NaN     Greg Daniels
# ..                                                 ...              ...
# 183                                                NaN        Matt Sohn
# 184                                                NaN     Jesse Peretz
# 185                                 Michael Imperioli     Jeffrey Blitz
# 186                                                NaN     David Rogers
# 187  Joan Cusack, Ed Begley Jr, Rachel Harris, Nanc...       Ken Kwapis
#
#                                               writers  has_guests  \
# 0    Ricky Gervais |Stephen Merchant and Greg Daniels       False
# 1                                         B. J. Novak       False
# 2                                    Paul Lieberstein       False
# 3                                       Michael Schur       False
# 4                                        Greg Daniels       False
# ..                                                ...         ...
# 183                                      Dan Sterling       False
# 184             Halsted Sullivan | Warren Lieberstein       False
# 185                              Niki Schwartz-Wright        True
# 186                                   Brent Forrester       False
# 187                                      Greg Daniels        True
#
#      scaled_ratings
# 0           0.28125
# 1           0.53125
# 2           0.37500
# 3           0.46875
# 4           0.56250
# ..              ...
# 183         0.43750
# 184         0.43750
# 185         0.75000
# 186         0.90625
# 187         1.00000
#
# [188 rows x 14 columns]

# %%
# Initiatlize an empty list
cols = []

# Iterate through the DataFrame, and assign colors based on the rating
for ind, row in office_df.iterrows():
    #print(row['scaled_ratings'])
    if row['scaled_ratings'] < 0.25:
        cols.append('red')
    #elif row['scaled_ratings'] >= 0.25 and row['scaled_ratings'] < 0.50:
    elif row['scaled_ratings'] < 0.50:
        cols.append('orange')
    #elif row['scaled_ratings'] >= 0.50 and row['scaled_ratings'] < 0.75:
    elif row['scaled_ratings'] < 0.75:
        cols.append('lightgreen')
    else:
        cols.append('darkgreen')

cols
# Out:
# ['orange',
#  'lightgreen',
#  'orange',
#  'orange',
#  'lightgreen',
#  'orange',
#  'lightgreen',
#  'orange',
#  'lightgreen',
#  'lightgreen',
#  'orange',
#  'orange',
#  'lightgreen',
#  'orange',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'darkgreen',
#  'lightgreen',
#  'orange',
#  'orange',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'orange',
#  'lightgreen',
#  'lightgreen',
#  'darkgreen',
#  'darkgreen',
#  'orange',
#  'lightgreen',
#  'orange',
#  'orange',
#  'orange',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'orange',
#  'orange',
#  'lightgreen',
#  'lightgreen',
#  'darkgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'darkgreen',
#  'darkgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'orange',
#  'lightgreen',
#  'darkgreen',
#  'orange',
#  'lightgreen',
#  'lightgreen',
#  'orange',
#  'darkgreen',
#  'lightgreen',
#  'lightgreen',
#  'orange',
#  'orange',
#  'orange',
#  'lightgreen',
#  'orange',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'orange',
#  'darkgreen',
#  'orange',
#  'orange',
#  'orange',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'darkgreen',
#  'lightgreen',
#  'lightgreen',
#  'darkgreen',
#  'lightgreen',
#  'orange',
#  'orange',
#  'darkgreen',
#  'darkgreen',
#  'orange',
#  'lightgreen',
#  'orange',
#  'orange',
#  'lightgreen',
#  'orange',
#  'lightgreen',
#  'lightgreen',
#  'red',
#  'orange',
#  'orange',
#  'lightgreen',
#  'lightgreen',
#  'orange',
#  'orange',
#  'lightgreen',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'lightgreen',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'darkgreen',
#  'lightgreen',
#  'orange',
#  'lightgreen',
#  'lightgreen',
#  'darkgreen',
#  'orange',
#  'darkgreen',
#  'orange',
#  'darkgreen',
#  'darkgreen',
#  'orange',
#  'lightgreen',
#  'lightgreen',
#  'orange',
#  'orange',
#  'red',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'red',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'red',
#  'red',
#  'red',
#  'red',
#  'orange',
#  'orange',
#  'orange',
#  'red',
#  'orange',
#  'orange',
#  'red',
#  'orange',
#  'orange',
#  'orange',
#  'lightgreen',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'red',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'orange',
#  'darkgreen',
#  'darkgreen',
#  'darkgreen']

# %%
# Initiatlize an empty list
sizes = []

# Iterate through the DataFrame, and assign a size based on whether it has guests 
for ind, row in office_df.iterrows():
    if row['has_guests'] == True:
        sizes.append(250)
    else:
        sizes.append(25)

sizes
# Out:
# [25,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  250,
#  250,
#  25,
#  25,
#  250,
#  25,
#  250,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  250,
#  250,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  25,
#  250,
#  250,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  25,
#  250,
#  25,
#  25,
#  250,
#  25,
#  250]

# %%
# For ease of plotting, add our lists as columns to the DataFrame
office_df['colors'] = cols
office_df['sizes'] = sizes

office_df.info()
office_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   episode_number  188 non-null    int64
#  1   season          188 non-null    int64
#  2   episode_title   188 non-null    object
#  3   description     188 non-null    object
#  4   ratings         188 non-null    float64
#  5   votes           188 non-null    int64
#  6   viewership_mil  188 non-null    float64
#  7   duration        188 non-null    int64
#  8   release_date    188 non-null    datetime64[ns]
#  9   guest_stars     29 non-null     object
#  10  director        188 non-null    object
#  11  writers         188 non-null    object
#  12  has_guests      188 non-null    bool
#  13  scaled_ratings  188 non-null    float64
#  14  colors          188 non-null    object
#  15  sizes           188 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(5), object(6)
# memory usage: 22.3+ KB
#      episode_number  season     episode_title  \
# 0                 0       1             Pilot
# 1                 1       1     Diversity Day
# 2                 2       1       Health Care
# 3                 3       1      The Alliance
# 4                 4       1        Basketball
# ..              ...     ...               ...
# 183             183       9     Stairmageddon
# 184             184       9    Paper Airplane
# 185             185       9  Livin' the Dream
# 186             186       9          A.A.R.M.
# 187             187       9            Finale
#
#                                            description  ratings  votes  \
# 0    The premiere episode introduces the boss and s...      7.5   4936
# 1    Michael's off color remark puts a sensitivity ...      8.3   4801
# 2    Michael leaves Dwight in charge of picking the...      7.8   4024
# 3    Just for a laugh, Jim agrees to an alliance wi...      8.1   3915
# 4    Michael and his staff challenge the warehouse ...      8.4   4294
# ..                                                 ...      ...    ...
# 183  Dwight shoots Stanley with a bull tranquilizer...      8.0   1985
# 184  The employees hold a paper airplane competitio...      8.0   2007
# 185  Dwight becomes regional manager after Andy qui...      9.0   2831
# 186  Dwight prepares for a marriage proposal and hi...      9.5   3914
# 187  One year later, Dunder Mifflin employees past ...      9.8  10515
#
#      viewership_mil  duration release_date  \
# 0             11.20        23   2005-03-24
# 1              6.00        23   2005-03-29
# 2              5.80        22   2005-04-05
# 3              5.40        23   2005-04-12
# 4              5.00        23   2005-04-19
# ..              ...       ...          ...
# 183            3.83        22   2013-04-11
# 184            3.25        22   2013-04-25
# 185            3.51        42   2013-05-02
# 186            4.56        43   2013-05-09
# 187            5.69        51   2013-05-16
#
#                                            guest_stars         director  \
# 0                                                  NaN       Ken Kwapis
# 1                                                  NaN       Ken Kwapis
# 2                                                  NaN  Ken Whittingham
# 3                                                  NaN     Bryan Gordon
# 4                                                  NaN     Greg Daniels
# ..                                                 ...              ...
# 183                                                NaN        Matt Sohn
# 184                                                NaN     Jesse Peretz
# 185                                 Michael Imperioli     Jeffrey Blitz
# 186                                                NaN     David Rogers
# 187  Joan Cusack, Ed Begley Jr, Rachel Harris, Nanc...       Ken Kwapis
#
#                                               writers  has_guests  \
# 0    Ricky Gervais |Stephen Merchant and Greg Daniels       False
# 1                                         B. J. Novak       False
# 2                                    Paul Lieberstein       False
# 3                                       Michael Schur       False
# 4                                        Greg Daniels       False
# ..                                                ...         ...
# 183                                      Dan Sterling       False
# 184             Halsted Sullivan | Warren Lieberstein       False
# 185                              Niki Schwartz-Wright        True
# 186                                   Brent Forrester       False
# 187                                      Greg Daniels        True
#
#      scaled_ratings      colors  sizes
# 0           0.28125      orange     25
# 1           0.53125  lightgreen     25
# 2           0.37500      orange     25
# 3           0.46875      orange     25
# 4           0.56250  lightgreen     25
# ..              ...         ...    ...
# 183         0.43750      orange     25
# 184         0.43750      orange     25
# 185         0.75000   darkgreen    250
# 186         0.90625   darkgreen     25
# 187         1.00000   darkgreen    250
#
# [188 rows x 16 columns]

# %%
# Split data into guest and non_guest DataFrames
non_guest_df = office_df[office_df['has_guests'] == False]
#print(non_guest_df)
non_guest_df.info()
non_guest_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159 entries, 0 to 186
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   episode_number  159 non-null    int64
#  1   season          159 non-null    int64
#  2   episode_title   159 non-null    object
#  3   description     159 non-null    object
#  4   ratings         159 non-null    float64
#  5   votes           159 non-null    int64
#  6   viewership_mil  159 non-null    float64
#  7   duration        159 non-null    int64
#  8   release_date    159 non-null    datetime64[ns]
#  9   guest_stars     0 non-null      object
#  10  director        159 non-null    object
#  11  writers         159 non-null    object
#  12  has_guests      159 non-null    bool
#  13  scaled_ratings  159 non-null    float64
#  14  colors          159 non-null    object
#  15  sizes           159 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(5), object(6)
# memory usage: 20.0+ KB
#      episode_number  season   episode_title  \
# 0                 0       1           Pilot
# 1                 1       1   Diversity Day
# 2                 2       1     Health Care
# 3                 3       1    The Alliance
# 4                 4       1      Basketball
# ..              ...     ...             ...
# 180             180       9       Moving On
# 181             181       9        The Farm
# 183             183       9   Stairmageddon
# 184             184       9  Paper Airplane
# 186             186       9        A.A.R.M.
#
#                                            description  ratings  votes  \
# 0    The premiere episode introduces the boss and s...      7.5   4936
# 1    Michael's off color remark puts a sensitivity ...      8.3   4801
# 2    Michael leaves Dwight in charge of picking the...      7.8   4024
# 3    Just for a laugh, Jim agrees to an alliance wi...      8.1   3915
# 4    Michael and his staff challenge the warehouse ...      8.4   4294
# ..                                                 ...      ...    ...
# 180  Andy finds out that Erin dumped him for Pete, ...      8.1   2089
# 181  Show follows Dwight Schrute a beet farmer runn...      7.5   2189
# 183  Dwight shoots Stanley with a bull tranquilizer...      8.0   1985
# 184  The employees hold a paper airplane competitio...      8.0   2007
# 186  Dwight prepares for a marriage proposal and hi...      9.5   3914
#
#      viewership_mil  duration release_date guest_stars          director  \
# 0             11.20        23   2005-03-24         NaN        Ken Kwapis
# 1              6.00        23   2005-03-29         NaN        Ken Kwapis
# 2              5.80        22   2005-04-05         NaN   Ken Whittingham
# 3              5.40        23   2005-04-12         NaN      Bryan Gordon
# 4              5.00        23   2005-04-19         NaN      Greg Daniels
# ..              ...       ...          ...         ...               ...
# 180            4.06        42   2013-02-14         NaN       Jon Favreau
# 181            3.54        22   2013-03-14         NaN  Paul Lieberstein
# 183            3.83        22   2013-04-11         NaN         Matt Sohn
# 184            3.25        22   2013-04-25         NaN      Jesse Peretz
# 186            4.56        43   2013-05-09         NaN      David Rogers
#
#                                               writers  has_guests  \
# 0    Ricky Gervais |Stephen Merchant and Greg Daniels       False
# 1                                         B. J. Novak       False
# 2                                    Paul Lieberstein       False
# 3                                       Michael Schur       False
# 4                                        Greg Daniels       False
# ..                                                ...         ...
# 180                                     Graham Wagner       False
# 181                                  Paul Lieberstein       False
# 183                                      Dan Sterling       False
# 184             Halsted Sullivan | Warren Lieberstein       False
# 186                                   Brent Forrester       False
#
#      scaled_ratings      colors  sizes
# 0           0.28125      orange     25
# 1           0.53125  lightgreen     25
# 2           0.37500      orange     25
# 3           0.46875      orange     25
# 4           0.56250  lightgreen     25
# ..              ...         ...    ...
# 180         0.46875      orange     25
# 181         0.28125      orange     25
# 183         0.43750      orange     25
# 184         0.43750      orange     25
# 186         0.90625   darkgreen     25
#
# [159 rows x 16 columns]

# %%
guest_df = office_df[office_df['has_guests'] == True]
#print(guest_df)
guest_df.info()
guest_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 5 to 187
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   episode_number  29 non-null     int64
#  1   season          29 non-null     int64
#  2   episode_title   29 non-null     object
#  3   description     29 non-null     object
#  4   ratings         29 non-null     float64
#  5   votes           29 non-null     int64
#  6   viewership_mil  29 non-null     float64
#  7   duration        29 non-null     int64
#  8   release_date    29 non-null     datetime64[ns]
#  9   guest_stars     29 non-null     object
#  10  director        29 non-null     object
#  11  writers         29 non-null     object
#  12  has_guests      29 non-null     bool
#  13  scaled_ratings  29 non-null     float64
#  14  colors          29 non-null     object
#  15  sizes           29 non-null     int64
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(5), object(6)
# memory usage: 3.7+ KB
#      episode_number  season         episode_title  \
# 5                 5       1              Hot Girl
# 8                 8       2       Office Olympics
# 9                 9       2              The Fire
# 12               12       2            The Client
# 14               14       2   E-Mail Surveillance
# 16               16       2          Booze Cruise
# 21               21       2       Valentine's Day
# 29               29       3        The Convention
# 53               53       4          Launch Party
# 66               66       5       Business Ethics
# 77               77       5         Stress Relief
# 82               82       5              New Boss
# 96               96       6                 Mafia
# 105             105       6                 Sabre
# 108             108       6  The Delivery: Part 2
# 117             117       7              Nepotism
# 121             121       7             The Sting
# 129             129       7           The Seminar
# 130             130       7            The Search
# 135             135       7          Training Day
# 144             144       8          Garden Party
# 149             149       8       Mrs. California
# 163             163       8              Turf War
# 169             169       9     Here Comes Treble
# 170             170       9              The Boat
# 174             174       9                  Lice
# 182             182       9                Promos
# 185             185       9      Livin' the Dream
# 187             187       9                Finale
#
#                                            description  ratings  votes  \
# 5    Michael is just one of the many male staff who...      7.7   3854
# 8    Ready to finalize his deal for a new condo, Mi...      8.4   3665
# 9    A fire in the kitchen relegates the staff to t...      8.4   3607
# 12   With Michael and Jan Levinson-Gould away from ...      8.6   3533
# 14   Michael decides to set up e-mail surveillance ...      8.4   3338
# 16   The Dunder Mifflin staff go on a mandatory "bo...      8.6   3536
# 21   When Michael visits Dunder Mifflin corporate h...      8.3   3104
# 29   Michael and Dwight go to a convention in Phila...      8.2   3027
# 53   The Dunder Mifflin Infinity website is launchi...      8.4   2844
# 66   A confession at an H.R. business ethics semina...      8.3   2654
# 77   Dwight's too-realistic fire alarm gives Stanle...      9.7   8170
# 82   Michael gets upset when he gets a new boss to ...      8.3   2503
# 96   Michael meets with an insurance salesman that ...      7.6   2464
# 105  Michael hates the changes that Dunder Mifflin'...      7.7   2251
# 108  After the baby is born, Pam has trouble gettin...      8.5   2370
# 117  Everybody demands that Michael fire the new of...      8.4   2520
# 121  Michael organizes a sting operation to find ou...      7.8   2156
# 129  Andy tries to host a small business seminar at...      7.6   2171
# 130  When Jim gets an emergency phone call from Hel...      8.5   2369
# 135  Michael makes fast friends with the man coming...      7.8   2215
# 144  Andy claims to be throwing a garden party at D...      8.1   2266
# 149  Robert brings his wife to the office so that s...      7.7   2050
# 163  Dwight and Jim fight with the Syracuse over a ...      7.6   1832
# 169  On Halloween, the Cornell a Capella group pays...      7.0   2021
# 170  Andy has one last chance to captain the family...      7.7   1955
# 174  Pam causes a lice outbreak but lets Meredith t...      7.6   1952
# 182  The release of the documentary promos creates ...      8.0   1924
# 185  Dwight becomes regional manager after Andy qui...      9.0   2831
# 187  One year later, Dunder Mifflin employees past ...      9.8  10515
#
#      viewership_mil  duration release_date  \
# 5              4.80        23   2005-04-26
# 8              8.30        22   2005-10-04
# 9              7.60        22   2005-10-11
# 12             7.50        22   2005-11-08
# 14             8.10        23   2005-11-22
# 16             8.70        22   2006-01-05
# 21             8.95        22   2006-02-09
# 29             7.78        22   2006-09-28
# 53             8.91        42   2007-10-11
# 66             8.99        22   2008-10-09
# 77            22.91        60   2009-02-01
# 82             7.95        30   2009-03-19
# 96             8.10        30   2009-10-15
# 105            7.36        30   2010-02-04
# 108            9.00        30   2010-03-04
# 117            8.40        30   2010-09-23
# 121            6.87        30   2010-10-21
# 129            7.93        30   2011-01-27
# 130            7.29        30   2011-02-03
# 135            7.87        30   2011-04-14
# 144            6.08        23   2011-10-13
# 149            5.71        23   2011-12-01
# 163            4.44        23   2012-05-03
# 169            4.00        22   2012-10-25
# 170            4.83        22   2012-11-08
# 174            4.54        22   2013-01-10
# 182            3.44        22   2013-04-04
# 185            3.51        42   2013-05-02
# 187            5.69        51   2013-05-16
#
#                                            guest_stars          director  \
# 5                                            Amy Adams    Amy Heckerling
# 8                                         Nancy Carell         Paul Feig
# 9                                            Amy Adams        Ken Kwapis
# 12                                         Tim Meadows      Greg Daniels
# 14                                           Ken Jeong         Paul Feig
# 16                                          Rob Riggle        Ken Kwapis
# 21                                       Conan O'Brien      Greg Daniels
# 29                                       Jerome Bettis   Ken Whittingham
# 53                                        Kevin McHale  See full summary
# 66                                Wendi McLendon-Covey     Jeffrey Blitz
# 77           Cloris Leachman, Jack Black, Jessica Alba     Jeffrey Blitz
# 82                                          Idris Elba         Paul Feig
# 96                                          Mike Starr      David Rogers
# 105                                   Christian Slater    John Krasinski
# 108                                      Mellisa Rauch      Harold Ramis
# 117                                        Evan Peters     Jeffrey Blitz
# 121                                   Timothy Olyphant   Randall Einhorn
# 129                                      Ricky Gervais        B.J. Novak
# 130  Will Arnett,  Ray Romano, Jim Carrey, Ricky Ge...  See full summary
# 135                                       Will Ferrell  Paul Lieberstein
# 144                       Josh Groban, Stephen Collins      David Rogers
# 149                                      Maura Tierney    Charlie Grandy
# 163                                        Chris Bauer       Daniel Chun
# 169                                    Stephen Colbert    Claire Scanlon
# 170                                        Josh Groban    John Krasinski
# 174                             Julius Winfield Erving    Rodman Flender
# 182                                        Ryan Howard  Jennifer Celotta
# 185                                 Michael Imperioli      Jeffrey Blitz
# 187  Joan Cusack, Ed Begley Jr, Rachel Harris, Nanc...        Ken Kwapis
#
#                                    writers  has_guests  scaled_ratings  \
# 5                             Mindy Kaling        True         0.34375
# 8                            Michael Schur        True         0.56250
# 9                              B. J. Novak        True         0.56250
# 12                        Paul Lieberstein        True         0.62500
# 14                        Jennifer Celotta        True         0.56250
# 16                            Greg Daniels        True         0.62500
# 21                           Michael Schur        True         0.53125
# 29         Gene Stupnitsky | Lee Eisenberg        True         0.50000
# 53                        Jennifer Celotta        True         0.56250
# 66                                Ryan Koh        True         0.53125
# 77                        Paul Lieberstein        True         0.96875
# 82         Lee Eisenberg | Gene Stupnitsky        True         0.53125
# 96                         Brent Forrester        True         0.31250
# 105                       Jennifer Celotta        True         0.34375
# 108                            Daniel Chun        True         0.59375
# 117                            Daniel Chun        True         0.56250
# 121                           Mindy Kaling        True         0.37500
# 129                             Steve Hely        True         0.31250
# 130                        Brent Forrester        True         0.59375
# 135                            Daniel Chun        True         0.37500
# 144                         Justin Spitzer        True         0.46875
# 149                            Dan Greaney        True         0.34375
# 163  Warren Lieberstein | Halsted Sullivan        True         0.31250
# 169                         Owen Ellickson        True         0.12500
# 170                           Dan Sterling        True         0.34375
# 174                   Niki Schwartz-Wright        True         0.31250
# 182                          Tim McAuliffe        True         0.43750
# 185                   Niki Schwartz-Wright        True         0.75000
# 187                           Greg Daniels        True         1.00000
#
#          colors  sizes
# 5        orange    250
# 8    lightgreen    250
# 9    lightgreen    250
# 12   lightgreen    250
# 14   lightgreen    250
# 16   lightgreen    250
# 21   lightgreen    250
# 29       orange    250
# 53   lightgreen    250
# 66   lightgreen    250
# 77    darkgreen    250
# 82   lightgreen    250
# 96       orange    250
# 105      orange    250
# 108  lightgreen    250
# 117  lightgreen    250
# 121      orange    250
# 129      orange    250
# 130  lightgreen    250
# 135      orange    250
# 144      orange    250
# 149      orange    250
# 163      orange    250
# 169         red    250
# 170      orange    250
# 174      orange    250
# 182      orange    250
# 185   darkgreen    250
# 187   darkgreen    250

# %%
# Create the figure
fig = plt.figure()
plt.style.use('fivethirtyeight')

# Create two scatter plots with the episode number on the x axis, and the viewership on the y axis
#plt.scatter(x=office_df['episode_number'],
#            #x=office_df['release_date'],
#            y=office_df['viewership_mil'],
#            color=cols,
#            sizes=sizes)

# Create a normal scatter plot for regular episodes
plt.scatter(x=non_guest_df['episode_number'],
            y=non_guest_df['viewership_mil'],
            color=non_guest_df['colors'],
            sizes=non_guest_df['sizes'])

# Create a starred scatterplot for guest star episodes
plt.scatter(x=guest_df['episode_number'],
            y=guest_df['viewership_mil'],
            color=guest_df['colors'],
            sizes=guest_df['sizes'],
            marker='*')

# Create a title
plt.title('Popularity, Quality, and Guest Appearances on the Office')
# Create an x-axis and y-axis label
plt.xlabel('Episode Number')
plt.ylabel('Viewership (Millions)')

# Show the plot
plt.show()

# %%
# Get the most popular guest star
#office_df[office_df['viewership_mil'] > 20]['guest_stars']
office_df[office_df['viewership_mil'] == office_df['viewership_mil'].max()]['guest_stars']
# Out:
# 77    Cloris Leachman, Jack Black, Jessica Alba
# Name: guest_stars, dtype: object

# %%
top_star = 'Jessica Alba'
